# %%
# %load_ext autoreload
# %autoreload 2
# to ensure kernel resets when files change around it

# %%
import numpy as np # main library for numeric calculations
import pandas as pd # main library for data analysis
import matplotlib.pyplot as plt # main library for data plotting
import seaborn as sns # Another library for data plotting with more functions
sns.set()

import scipy as scp # STEM software
from scipy import signal
import scipy.interpolate as interpolate

from glob import glob # check files
from IPython.display import display, Markdown

import sys, os

from sympy import *

file_path = os.getcwd()
print(file_path)
parent_dir = "\\".join(file_path.split("\\")[:-1])
print(parent_dir)

sys.path.append(parent_dir)

from mathepy.calculus import *

"""
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)"""

import warnings
warnings.filterwarnings('ignore') # literally to ignore all the warnings that don't matter


def printf(*args, sep=" ", end="\n"):
    string = sep.join([str(i) for i in args])+end
    display(Markdown(string))
# Out:
# C:\Users\Prannaya\mathepy\test
# C:\Users\Prannaya\mathepy

# %%
init_printing()
init_session()
# Out:
# IPython console for SymPy 1.4 (Python 3.7.2-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.4/

# %%
x * y
# Out:
# x⋅y

# %%
solved = solve(Eq(exp(sin(x))+x*y, y**3 + sec(x)))
solved[0][y]
# Out:
#
#
#
#
#
#
#                                         x
# - ────────────────────────────────────────────────────────────────────────────
#          _____________________________________________________________________
#         ╱     ________________________________________
#        ╱     ╱                                      2
#       ╱     ╱         3   ⎛      sin(x)            ⎞         sin(x)
#      ╱    ╲╱   - 108⋅x  + ⎝- 27⋅ℯ       + 27⋅sec(x)⎠     27⋅ℯ         27⋅sec(x
#   3 ╱     ──────────────────────────────────────────── - ────────── + ────────
#   ╲╱                           2                             2            2
#
#             __________________________________________________________________
#            ╱     ________________________________________
#           ╱     ╱                                      2
#          ╱     ╱         3   ⎛      sin(x)            ⎞         sin(x)
#         ╱    ╲╱   - 108⋅x  + ⎝- 27⋅ℯ       + 27⋅sec(x)⎠     27⋅ℯ         27⋅se
#      3 ╱     ──────────────────────────────────────────── - ────────── + ─────
#      ╲╱                           2                             2            2
# ── - ─────────────────────────────────────────────────────────────────────────
# __                                         3
#
#
#
# )
# ─
#
#
# _____
#
#
#
# c(x)
# ────
#
# ─────

# %%
simplify(solved[0][y])
# Out:
#       ⎛
#       ⎜          ⎛         ___________________________________
#       ⎜          ⎜        ╱                                 2
#       ⎜3 ___     ⎜       ╱       3      ⎛   sin(x)         ⎞         sin(x)
#   2/3 ⎜╲╱ 2 ⋅x   ⎝6⋅√3⋅╲╱   - 4⋅x  + 27⋅⎝- ℯ       + sec(x)⎠   - 54⋅ℯ       +
# -3   ⋅⎜─────── + ─────────────────────────────────────────────────────────────
#       ⎝   3                                          18
# ──────────────────────────────────────────────────────────────────────────────
#                 ______________________________________________________________
#                ╱        ___________________________________
#               ╱        ╱                                 2
#            3 ╱        ╱       3      ⎛   sin(x)         ⎞        sin(x)
#            ╲╱    √3⋅╲╱   - 4⋅x  + 27⋅⎝- ℯ       + sec(x)⎠   - 9⋅ℯ       + 9⋅se
#
#           2/3⎞
#          ⎞   ⎟
#          ⎟   ⎟
#          ⎟   ⎟
# 54⋅sec(x)⎠   ⎟
# ─────────────⎟
#              ⎠
# ───────────────
# _____
#
#
#
# c(x)

# %%
simplify(diff(simplify(solved[0][y]), x))
# Out:
#      ⎛        ⎛
#      ⎜        ⎜            ⎛         ___________________________________
#      ⎜        ⎜            ⎜        ╱                                 2
#      ⎜  3 ___ ⎜  3 ___     ⎜       ╱       3      ⎛   sin(x)         ⎞
#  2/3 ⎜  ╲╱ 2 ⋅⎝6⋅╲╱ 2 ⋅x + ⎝6⋅√3⋅╲╱   - 4⋅x  + 27⋅⎝- ℯ       + sec(x)⎠   - 54⋅
# 6   ⋅⎜- ──────────────────────────────────────────────────────────────────────
#      ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                     2/3⎞
#                    ⎞   ⎟ ⎛
#                    ⎟   ⎟ ⎜
#  sin(x)            ⎟   ⎟ ⎜   ⎛   2     ⎛   sin(x)                       ⎞ ⎛
# ℯ       + 54⋅sec(x)⎠   ⎠⋅⎝√3⋅⎝2⋅x  - 9⋅⎝- ℯ      ⋅cos(x) + tan(x)⋅sec(x)⎠⋅⎝- ℯ
# ──────────────────────────────────────────────────────────────────────────────
#                                                     36
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#                         ___________________________________
#                        ╱                                 2
# sin(x)         ⎞⎞     ╱       3      ⎛   sin(x)         ⎞   ⎛   sin(x)
#        + sec(x)⎠⎠ + ╲╱   - 4⋅x  + 27⋅⎝- ℯ       + sec(x)⎠  ⋅⎝3⋅ℯ      ⋅cos(x)
# ──────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                       ⎛
#                   ⎞   ⎜
#                   ⎟   ⎜
#                  ⎞⎟   ⎜   ⎛   2      ⎛ sin(x)                       ⎞ ⎛ sin(x)
# - 3⋅tan(x)⋅sec(x)⎠⎠   ⎝√3⋅⎝8⋅x  - 36⋅⎝ℯ      ⋅cos(x) - tan(x)⋅sec(x)⎠⋅⎝ℯ
# ─────────────────── + ────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                   ___________________________________ ⎛       ________________
#                  ╱                                 2  ⎜      ╱
#                 ╱       3      ⎛   sin(x)         ⎞   ⎜     ╱       3      ⎛
#               ╲╱   - 4⋅x  + 27⋅⎝- ℯ       + sec(x)⎠  ⋅⎝√3⋅╲╱   - 4⋅x  + 27⋅⎝-
#
#
#                   ___________________________________
#                  ╱                                 2
#          ⎞⎞     ╱       3      ⎛   sin(x)         ⎞   ⎛    sin(x)
#  - sec(x)⎠⎠ + ╲╱   - 4⋅x  + 27⋅⎝- ℯ       + sec(x)⎠  ⋅⎝12⋅ℯ      ⋅cos(x) - 12⋅
# ──────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
#                                            4/3
# ___________________                       ⎞
#                  2                        ⎟
#  sin(x)         ⎞        sin(x)           ⎟
# ℯ       + sec(x)⎠   - 9⋅ℯ       + 9⋅sec(x)⎠
#
#                                                                 ______________
#                        ___________________________________     ╱           ___
#                       ╱                                 2     ╱           ╱
#              ⎞       ╱       3      ⎛   sin(x)         ⎞   3 ╱           ╱
# tan(x)⋅sec(x)⎠ - 2⋅╲╱   - 4⋅x  + 27⋅⎝- ℯ       + sec(x)⎠  ⋅╲╱    12⋅√3⋅╲╱   -
# ──────────────────────────────────────────────────────────────────────────────
#                                        36
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
# ____________________________________________________________⎞
# ________________________________                            ⎟ ⎛         ______
#                               2                             ⎟ ⎜        ╱
#    3      ⎛   sin(x)         ⎞          sin(x)              ⎟ ⎜       ╱
# 4⋅x  + 27⋅⎝- ℯ       + sec(x)⎠   - 108⋅ℯ       + 108⋅sec(x) ⎠⋅⎝3⋅√3⋅╲╱   - 4⋅x
# ──────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                                                        2/3⎞
# _____________________________                         ⎞   ⎟
#                            2                          ⎟   ⎟
# 3      ⎛   sin(x)         ⎞         sin(x)            ⎟   ⎟
#   + 27⋅⎝- ℯ       + sec(x)⎠   - 27⋅ℯ       + 27⋅sec(x)⎠   ⎟
# ──────────────────────────────────────────────────────────⎟
#                                                           ⎠
# ───────────────────────────────────────────────────────────

# %%
simplify(diff(simplify(solved[0][y]), x)).subs(simplify(solved[0][y]), y)
# Out:
#      ⎛        ⎛
#      ⎜        ⎜            ⎛         ___________________________________
#      ⎜        ⎜            ⎜        ╱                                 2
#      ⎜  3 ___ ⎜  3 ___     ⎜       ╱       3      ⎛   sin(x)         ⎞
#  2/3 ⎜  ╲╱ 2 ⋅⎝6⋅╲╱ 2 ⋅x + ⎝6⋅√3⋅╲╱   - 4⋅x  + 27⋅⎝- ℯ       + sec(x)⎠   - 54⋅
# 6   ⋅⎜- ──────────────────────────────────────────────────────────────────────
#      ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                     2/3⎞
#                    ⎞   ⎟ ⎛
#                    ⎟   ⎟ ⎜
#  sin(x)            ⎟   ⎟ ⎜   ⎛   2     ⎛   sin(x)                       ⎞ ⎛
# ℯ       + 54⋅sec(x)⎠   ⎠⋅⎝√3⋅⎝2⋅x  - 9⋅⎝- ℯ      ⋅cos(x) + tan(x)⋅sec(x)⎠⋅⎝- ℯ
# ──────────────────────────────────────────────────────────────────────────────
#                                                     36
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#                         ___________________________________
#                        ╱                                 2
# sin(x)         ⎞⎞     ╱       3      ⎛   sin(x)         ⎞   ⎛   sin(x)
#        + sec(x)⎠⎠ + ╲╱   - 4⋅x  + 27⋅⎝- ℯ       + sec(x)⎠  ⋅⎝3⋅ℯ      ⋅cos(x)
# ──────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                       ⎛
#                   ⎞   ⎜
#                   ⎟   ⎜
#                  ⎞⎟   ⎜   ⎛   2      ⎛ sin(x)                       ⎞ ⎛ sin(x)
# - 3⋅tan(x)⋅sec(x)⎠⎠   ⎝√3⋅⎝8⋅x  - 36⋅⎝ℯ      ⋅cos(x) - tan(x)⋅sec(x)⎠⋅⎝ℯ
# ─────────────────── + ────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                   ___________________________________ ⎛       ________________
#                  ╱                                 2  ⎜      ╱
#                 ╱       3      ⎛   sin(x)         ⎞   ⎜     ╱       3      ⎛
#               ╲╱   - 4⋅x  + 27⋅⎝- ℯ       + sec(x)⎠  ⋅⎝√3⋅╲╱   - 4⋅x  + 27⋅⎝-
#
#
#                   ___________________________________
#                  ╱                                 2
#          ⎞⎞     ╱       3      ⎛   sin(x)         ⎞   ⎛    sin(x)
#  - sec(x)⎠⎠ + ╲╱   - 4⋅x  + 27⋅⎝- ℯ       + sec(x)⎠  ⋅⎝12⋅ℯ      ⋅cos(x) - 12⋅
# ──────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
#                                            4/3
# ___________________                       ⎞
#                  2                        ⎟
#  sin(x)         ⎞        sin(x)           ⎟
# ℯ       + sec(x)⎠   - 9⋅ℯ       + 9⋅sec(x)⎠
#
#                                                                 ______________
#                        ___________________________________     ╱           ___
#                       ╱                                 2     ╱           ╱
#              ⎞       ╱       3      ⎛   sin(x)         ⎞   3 ╱           ╱
# tan(x)⋅sec(x)⎠ - 2⋅╲╱   - 4⋅x  + 27⋅⎝- ℯ       + sec(x)⎠  ⋅╲╱    12⋅√3⋅╲╱   -
# ──────────────────────────────────────────────────────────────────────────────
#                                        36
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
# ____________________________________________________________⎞
# ________________________________                            ⎟ ⎛         ______
#                               2                             ⎟ ⎜        ╱
#    3      ⎛   sin(x)         ⎞          sin(x)              ⎟ ⎜       ╱
# 4⋅x  + 27⋅⎝- ℯ       + sec(x)⎠   - 108⋅ℯ       + 108⋅sec(x) ⎠⋅⎝3⋅√3⋅╲╱   - 4⋅x
# ──────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                                                        2/3⎞
# _____________________________                         ⎞   ⎟
#                            2                          ⎟   ⎟
# 3      ⎛   sin(x)         ⎞         sin(x)            ⎟   ⎟
#   + 27⋅⎝- ℯ       + sec(x)⎠   - 27⋅ℯ       + 27⋅sec(x)⎠   ⎟
# ──────────────────────────────────────────────────────────⎟
#                                                           ⎠
# ───────────────────────────────────────────────────────────

# %%
integrate((x**2 - 1)/(x**3 - 3*x + 1), x)
# Out:
#    ⎛ 3          ⎞
# log⎝x  - 3⋅x + 1⎠
# ─────────────────
#         3
